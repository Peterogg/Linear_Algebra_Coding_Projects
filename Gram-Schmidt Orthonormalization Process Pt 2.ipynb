# %% [markdown]
# <a href="https://colab.research.google.com/github/Peterogg/Linear_Algebra_Coding_Projects/blob/main/Gram-Schmidt%20Orthonormalization%20Process%20Pt%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sympy import Poly
import sympy as sym
import numpy as np
from numpy import c_

# We'll specify that x and t are variables:
x, t = sym.symbols('x, t')

ll = "loaded"

# %%
# Create a vector
r = np.matrix('1;2;3;4')

r.dot(r)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-90de2c31dc9f> in <module>()
#       2 r = np.matrix('1;2;3;4')
#       3
# ----> 4 r.dot(r)
#
# ValueError: shapes (4,1) and (4,1) not aligned: 1 (dim 1) != 4 (dim 0)

# %%
# create a vector as an array
s4 = np.array([1, 2, 3, 4])
s4.dot(s4)
# Out:
# 30

# %%
# the size of s4
np.sqrt(s4.dot(s4))
# Out:
# 5.477225575051661

# %%
# Using the Grahm-Schmidt Orthonormalization Process
r1 = np.array([3, 0, 3, 0])
r2 = np.array([3, 2, 3, 3])
r3 = np.array([-7, -4, -5, -6])
r4 = np.array([-7, -3, -11, 2])

# %%
# find the first nice messy vector
t1 = r1
# subtract off nice basis vectors

# find magnitude of t1
n1 = np.sqrt(t1.dot(t1))

#so u1 = (1/n1) * t1
u1 = (1/n1) * t1
u1
# Out:
# array([0.70710678, 0.        , 0.70710678, 0.        ])

# %%
#verify u1 has size 1 and is orthoganal to all other u vectors
u1.dot(u1)
# Out:
# 1.0000000000000002

# %%
# find the first nice messy vector
t2 = r2 - r2.dot(u1) * u1
# subtract off nice basis vectors

# find magnitude of t1
n2 = np.sqrt(t2.dot(t2))

#so u2 = (1/n2) * t2
u2 = (1/n2) * t2
u2
print("The squared size of u2 is  ", u2.dot(u2))
print(u2)
# Out:
# The squared size of u2 is   1.0
# [-1.23168186e-16  5.54700196e-01 -1.23168186e-16  8.32050294e-01]

# %%
# find the first nice messy vector
t3 = r3 - r3.dot(u2) * u2 -r3.dot(u1) * u1
# subtract off nice basis vectors

# find magnitude of t1
n3 = np.sqrt(t3.dot(t3))

#so u3 = (1/n3) * t3
u3 = (1/n3) * t3
print(u3)
print("The squared size of u3 is  ", u3.dot(u3))
print("u3.u2 = ", u3.dot(u2))
# Out:
# [-7.07106781e-01 -3.14018492e-16  7.07106781e-01 -6.28036983e-16]
# The squared size of u3 is   0.9999999999999998
# u3.u2 =  -6.967444759389139e-16

# %%
# find the first nice messy vector
t4 = r4 - r4.dot(u2) * u2 -r4.dot(u1) * u1 - r4.dot(u3) * u3
# subtract off nice basis vectors

# find magnitude of t1
n4 = np.sqrt(t4.dot(t4))

#so u43 = (1/n4) * t4
u4 = (1/n4) * t4
print(u4)
print("The squared size of u4 is  ", u4.dot(u4))
print("u4.u3 = ", u4.dot(u3))
# Out:
# [-1.23168186e-16 -8.32050294e-01  1.23168186e-16  5.54700196e-01]
# The squared size of u4 is   1.0000000000000002
# u4.u3 =  8.709305949236507e-17

# %%
r4.dot(u4)
# Out:
# 3.6055512754639887

# %%
# Out:
# [[  7  -9  14]
#  [-47 -21 -71]
#  [ 12   8  12]]
# [[ 25   4  11]
#  [-41  17  -2]
#  [-89 -29 -44]]
# 3067.9999999999973
# 3067.9999999999973
# -58.999999999999964
# -51.999999999999986
